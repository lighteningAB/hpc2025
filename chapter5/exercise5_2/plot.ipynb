# %%
import matplotlib.pyplot as plt
import numpy as np

# Read the CSV file
data = np.loadtxt('vector_evolution.csv', delimiter=',')

# Create x coordinates (evenly spaced from 0 to 1)
x = np.linspace(0, 1, data.shape[1])

# Create a color gradient from blue to red
colors = plt.cm.coolwarm(np.linspace(0, 1, data.shape[0]))

# Create the plot
plt.figure(figsize=(10, 6))

# Plot each time step with a different color
for i, row in enumerate(data):
    plt.plot(x, row, color=colors[i], alpha=0.5, label=f't={i}' if i % 5 == 0 else "")

# Customize the plot
plt.xlabel('x')
plt.ylabel('y')
plt.title('Evolution of y coordinates over time')
plt.grid(True, alpha=0.3)

# Add legend for every 5th time step to avoid overcrowding
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Adjust layout to prevent legend from being cut off
plt.tight_layout()

# Show the plot
plt.show()
